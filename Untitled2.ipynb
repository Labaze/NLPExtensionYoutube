# %%
# !conda env list
# Out:
# # conda environments:
# #
#                          /Users/basile/Desktop/Master Thesis/ENTER
# base                     /Users/basile/anaconda3
# Bert                     /Users/basile/anaconda3/envs/Bert
# NLP                   *  /Users/basile/anaconda3/envs/NLP

# %%
# !pip install bert-extractive-summarizer
# Out:
# Processing /Users/basile/Library/Caches/pip/wheels/72/dc/37/8f4d3e5a337d48b296ebe21196d99dd5a52d494411b5ff9825/bert_extractive_summarizer-0.4.2-py3-none-any.whl
# Collecting spacy
#   Using cached spacy-2.2.4-cp37-cp37m-macosx_10_9_x86_64.whl (10.5 MB)
# Collecting transformers
#   Using cached transformers-2.10.0-py3-none-any.whl (660 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-0.23.1-cp37-cp37m-macosx_10_9_x86_64.whl (7.2 MB)
# Collecting requests<3.0.0,>=2.13.0
#   Using cached requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Collecting wasabi<1.1.0,>=0.4.0
#   Using cached wasabi-0.6.0-py3-none-any.whl (20 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.3-cp37-cp37m-macosx_10_6_intel.whl (54 kB)
# Collecting catalogue<1.1.0,>=0.0.7
#   Using cached catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Collecting srsly<1.1.0,>=1.0.2
#   Using cached srsly-1.0.2-cp37-cp37m-macosx_10_9_x86_64.whl (182 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.2-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (34 kB)
# Collecting blis<0.5.0,>=0.4.0
#   Using cached blis-0.4.1-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (4.0 MB)
# Collecting thinc==7.4.0
#   Using cached thinc-7.4.0-cp37-cp37m-macosx_10_9_x86_64.whl (2.2 MB)
# Requirement already satisfied: setuptools in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from spacy->bert-extractive-summarizer) (46.4.0.post20200518)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.2-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (211 kB)
# Collecting plac<1.2.0,>=0.9.6
#   Using cached plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting tqdm<5.0.0,>=4.38.0
#   Using cached tqdm-4.46.0-py2.py3-none-any.whl (63 kB)
# Collecting numpy>=1.15.0
#   Using cached numpy-1.18.4-cp37-cp37m-macosx_10_9_x86_64.whl (15.1 MB)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.91-cp37-cp37m-macosx_10_6_x86_64.whl (1.1 MB)
# Processing /Users/basile/Library/Caches/pip/wheels/69/09/d1/bf058f7d6fa0ecba2ce7c66be3b8d012beb4bf61a6e0c101c0/sacremoses-0.0.43-py3-none-any.whl
# Collecting tokenizers==0.7.0
#   Using cached tokenizers-0.7.0-cp37-cp37m-macosx_10_10_x86_64.whl (1.2 MB)
# Processing /Users/basile/Library/Caches/pip/wheels/d4/9f/f1/da2c5e041f3f291659e2aca93cbe48355347b3e9e7c836ec08/regex-2020.5.14-cp37-cp37m-macosx_10_14_x86_64.whl
# Collecting filelock
#   Using cached filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Collecting joblib>=0.11
#   Using cached joblib-0.15.1-py3-none-any.whl (298 kB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-2.0.0-py3-none-any.whl (34 kB)
# Collecting scipy>=0.19.1
#   Using cached scipy-1.4.1-cp37-cp37m-macosx_10_6_intel.whl (28.4 MB)
# Collecting idna<3,>=2.5
#   Using cached idna-2.9-py2.py3-none-any.whl (58 kB)
# Collecting chardet<4,>=3.0.2
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer) (2020.4.5.1)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Using cached urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
# Collecting importlib-metadata>=0.20; python_version < "3.8"
#   Downloading importlib_metadata-1.6.0-py2.py3-none-any.whl (30 kB)
# Collecting click
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting six
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Installing collected packages: idna, chardet, urllib3, requests, wasabi, cymem, zipp, importlib-metadata, catalogue, srsly, murmurhash, numpy, blis, preshed, tqdm, plac, thinc, spacy, sentencepiece, regex, joblib, click, six, sacremoses, tokenizers, filelock, transformers, threadpoolctl, scipy, scikit-learn, bert-extractive-summarizer
# Successfully installed bert-extractive-summarizer-0.4.2 blis-0.4.1 catalogue-1.0.0 chardet-3.0.4 click-7.1.2 cymem-2.0.3 filelock-3.0.12 idna-2.9 importlib-metadata-1.6.0 joblib-0.15.1 murmurhash-1.0.2 numpy-1.18.4 plac-1.1.3 preshed-3.0.2 regex-2020.5.14 requests-2.23.0 sacremoses-0.0.43 scikit-learn-0.23.1 scipy-1.4.1 sentencepiece-0.1.91 six-1.15.0 spacy-2.2.4 srsly-1.0.2 thinc-7.4.0 threadpoolctl-2.0.0 tokenizers-0.7.0 tqdm-4.46.0 transformers-2.10.0 urllib3-1.25.9 wasabi-0.6.0 zipp-3.1.0

# %%
# !pip install spacy==2.1.3
# !pip install transformers==2.2.2
# !pip install neuralcoref
# Out:
# Processing /Users/basile/Library/Caches/pip/wheels/95/95/a9/338c51c9549978f952a667b9542ed200968ab79211654d444f/spacy-2.1.3-cp37-cp37m-macosx_10_9_x86_64.whl
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from spacy==2.1.3) (2.23.0)
# Requirement already satisfied: srsly<1.1.0,>=0.0.5 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from spacy==2.1.3) (1.0.2)
# Collecting plac<1.0.0,>=0.9.6
#   Using cached plac-0.9.6-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: numpy>=1.15.0 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from spacy==2.1.3) (1.18.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from spacy==2.1.3) (0.6.0)
# Collecting thinc<7.1.0,>=7.0.2
#   Using cached thinc-7.0.8-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (2.9 MB)
# Collecting blis<0.3.0,>=0.2.2
#   Using cached blis-0.2.4-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.0 MB)
# Collecting jsonschema<3.0.0,>=2.6.0
#   Using cached jsonschema-2.6.0-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from spacy==2.1.3) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from spacy==2.1.3) (2.0.3)
# Collecting preshed<2.1.0,>=2.0.1
#   Using cached preshed-2.0.1-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (145 kB)
# Requirement already satisfied: idna<3,>=2.5 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.1.3) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.1.3) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.1.3) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.1.3) (3.0.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from thinc<7.1.0,>=7.0.2->spacy==2.1.3) (4.46.0)
# Installing collected packages: plac, preshed, blis, thinc, jsonschema, spacy
#   Attempting uninstall: plac
#     Found existing installation: plac 1.1.3
#     Uninstalling plac-1.1.3:
#       Successfully uninstalled plac-1.1.3
#   Attempting uninstall: preshed
#     Found existing installation: preshed 3.0.2
#     Uninstalling preshed-3.0.2:
#       Successfully uninstalled preshed-3.0.2
#   Attempting uninstall: blis
#     Found existing installation: blis 0.4.1
#     Uninstalling blis-0.4.1:
#       Successfully uninstalled blis-0.4.1
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# Successfully installed blis-0.2.4 jsonschema-2.6.0 plac-0.9.6 preshed-2.0.1 spacy-2.1.3 thinc-7.0.8
# Collecting transformers==2.2.2
#   Using cached transformers-2.2.2-py3-none-any.whl (387 kB)
# Requirement already satisfied: requests in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from transformers==2.2.2) (2.23.0)
# Requirement already satisfied: sacremoses in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from transformers==2.2.2) (0.0.43)
# Requirement already satisfied: numpy in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from transformers==2.2.2) (1.18.4)
# Requirement already satisfied: tqdm in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from transformers==2.2.2) (4.46.0)
# Collecting boto3
#   Using cached boto3-1.13.16-py2.py3-none-any.whl (128 kB)
# Requirement already satisfied: regex in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from transformers==2.2.2) (2020.5.14)
# Requirement already satisfied: sentencepiece in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from transformers==2.2.2) (0.1.91)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from requests->transformers==2.2.2) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from requests->transformers==2.2.2) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from requests->transformers==2.2.2) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from requests->transformers==2.2.2) (3.0.4)
# Requirement already satisfied: six in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from sacremoses->transformers==2.2.2) (1.15.0)
# Requirement already satisfied: click in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from sacremoses->transformers==2.2.2) (7.1.2)
# Requirement already satisfied: joblib in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from sacremoses->transformers==2.2.2) (0.15.1)
# Collecting botocore<1.17.0,>=1.16.16
#   Using cached botocore-1.16.16-py2.py3-none-any.whl (6.2 MB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Using cached s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting python-dateutil<3.0.0,>=2.1
#   Using cached python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting docutils<0.16,>=0.10
#   Using cached docutils-0.15.2-py3-none-any.whl (547 kB)
# Installing collected packages: python-dateutil, docutils, jmespath, botocore, s3transfer, boto3, transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 2.10.0
#     Uninstalling transformers-2.10.0:
#       Successfully uninstalled transformers-2.10.0
# Successfully installed boto3-1.13.16 botocore-1.16.16 docutils-0.15.2 jmespath-0.10.0 python-dateutil-2.8.1 s3transfer-0.3.3 transformers-2.2.2
# Collecting neuralcoref
#   Using cached neuralcoref-4.0-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (513 kB)
# Requirement already satisfied: boto3 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from neuralcoref) (1.13.16)
# Requirement already satisfied: spacy>=2.1.0 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from neuralcoref) (2.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from neuralcoref) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from neuralcoref) (1.18.4)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from boto3->neuralcoref) (0.10.0)
# Requirement already satisfied: botocore<1.17.0,>=1.16.16 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from boto3->neuralcoref) (1.16.16)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from boto3->neuralcoref) (0.3.3)
# Requirement already satisfied: jsonschema<3.0.0,>=2.6.0 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from spacy>=2.1.0->neuralcoref) (2.6.0)
# Requirement already satisfied: thinc<7.1.0,>=7.0.2 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from spacy>=2.1.0->neuralcoref) (7.0.8)
# Requirement already satisfied: blis<0.3.0,>=0.2.2 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from spacy>=2.1.0->neuralcoref) (0.2.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from spacy>=2.1.0->neuralcoref) (2.0.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from spacy>=2.1.0->neuralcoref) (0.6.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from spacy>=2.1.0->neuralcoref) (1.0.2)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from spacy>=2.1.0->neuralcoref) (0.9.6)
# Requirement already satisfied: srsly<1.1.0,>=0.0.5 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from spacy>=2.1.0->neuralcoref) (1.0.2)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from spacy>=2.1.0->neuralcoref) (2.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (2020.4.5.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from botocore<1.17.0,>=1.16.16->boto3->neuralcoref) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from botocore<1.17.0,>=1.16.16->boto3->neuralcoref) (2.8.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from thinc<7.1.0,>=7.0.2->spacy>=2.1.0->neuralcoref) (4.46.0)
# Requirement already satisfied: six>=1.5 in /Users/basile/anaconda3/envs/Bert/lib/python3.7/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.17.0,>=1.16.16->boto3->neuralcoref) (1.15.0)
# Installing collected packages: neuralcoref
# Successfully installed neuralcoref-4.0

# %%
from summarizer import Summarizer

body = 'Text body that you want to summarize with BERT'
body2 = 'Something else you want to summarize with BERT'
model = Summarizer()
model(body)
model(body2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/anaconda3/envs/NLP/lib/python3.7/site-packages/tqdm/notebook.py in status_printer(_, total, desc, ncols)
#      95             if total:
# ---> 96                 pbar = IProgress(min=0, max=total)
#      97             else:  # No total? Show info style bar with no progress tqdm status
#
# NameError: name 'IProgress' is not defined
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-3b4384c20fe2> in <module>
#       3 body = 'Text body that you want to summarize with BERT'
#       4 body2 = 'Something else you want to summarize with BERT'
# ----> 5 model = Summarizer()
#       6 model(body)
#       7 model(body2)
#
# ~/anaconda3/envs/NLP/lib/python3.7/site-packages/summarizer/model_processors.py in __init__(self, model, custom_model, custom_tokenizer, hidden, reduce_option, sentence_handler, random_state)
#     174         """
#     175         super(Summarizer, self).__init__(
# --> 176             model, custom_model, custom_tokenizer, hidden, reduce_option, sentence_handler, random_state
#     177         )
#     178
#
# ~/anaconda3/envs/NLP/lib/python3.7/site-packages/summarizer/model_processors.py in __init__(self, model, custom_model, custom_tokenizer, hidden, reduce_option, sentence_handler, random_state)
#     135             model=model, custom_model=custom_model, custom_tokenizer=custom_tokenizer,
#     136             hidden=hidden, reduce_option=reduce_option,
# --> 137             sentence_handler=sentence_handler, random_state=random_state
#     138         )
#     139
#
# ~/anaconda3/envs/NLP/lib/python3.7/site-packages/summarizer/model_processors.py in __init__(self, model, custom_model, custom_tokenizer, hidden, reduce_option, sentence_handler, random_state)
#      33
#      34         np.random.seed(random_state)
# ---> 35         self.model = BertParent(model, custom_model, custom_tokenizer)
#      36         self.hidden = hidden
#      37         self.reduce_option = reduce_option
#
# ~/anaconda3/envs/NLP/lib/python3.7/site-packages/summarizer/bert_parent.py in __init__(self, model, custom_model, custom_tokenizer)
#      44             self.model = custom_model.to(self.device)
#      45         else:
# ---> 46             self.model = base_model.from_pretrained(model, output_hidden_states=True).to(self.device)
#      47
#      48         if custom_tokenizer:
#
# ~/anaconda3/envs/NLP/lib/python3.7/site-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     577                 proxies=proxies,
#     578                 local_files_only=local_files_only,
# --> 579                 **kwargs,
#     580             )
#     581         else:
#
# ~/anaconda3/envs/NLP/lib/python3.7/site-packages/transformers/configuration_utils.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     200
#     201         """
# --> 202         config_dict, kwargs = cls.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     203         return cls.from_dict(config_dict, **kwargs)
#     204
#
# ~/anaconda3/envs/NLP/lib/python3.7/site-packages/transformers/configuration_utils.py in get_config_dict(cls, pretrained_model_name_or_path, pretrained_config_archive_map, **kwargs)
#     247                 proxies=proxies,
#     248                 resume_download=resume_download,
# --> 249                 local_files_only=local_files_only,
#     250             )
#     251             # Load config dict
#
# ~/anaconda3/envs/NLP/lib/python3.7/site-packages/transformers/file_utils.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, local_files_only)
#     257             resume_download=resume_download,
#     258             user_agent=user_agent,
# --> 259             local_files_only=local_files_only,
#     260         )
#     261     elif os.path.exists(url_or_filename):
#
# ~/anaconda3/envs/NLP/lib/python3.7/site-packages/transformers/file_utils.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, local_files_only)
#     436             logger.info("%s not found in cache or force_download set to True, downloading to %s", url, temp_file.name)
#     437
# --> 438             http_get(url, temp_file, proxies=proxies, resume_size=resume_size, user_agent=user_agent)
#     439
#     440         logger.info("storing %s in cache at %s", url, cache_path)
#
# ~/anaconda3/envs/NLP/lib/python3.7/site-packages/transformers/file_utils.py in http_get(url, temp_file, proxies, resume_size, user_agent)
#     327         initial=resume_size,
#     328         desc="Downloading",
# --> 329         disable=bool(logger.getEffectiveLevel() == logging.NOTSET),
#     330     )
#     331     for chunk in response.iter_content(chunk_size=1024):
#
# ~/anaconda3/envs/NLP/lib/python3.7/site-packages/tqdm/notebook.py in __init__(self, *args, **kwargs)
#     207         total = self.total * unit_scale if self.total else self.total
#     208         self.container = self.status_printer(
# --> 209             self.fp, total, self.desc, self.ncols)
#     210         self.sp = self.display
#     211
#
# ~/anaconda3/envs/NLP/lib/python3.7/site-packages/tqdm/notebook.py in status_printer(_, total, desc, ncols)
#     102             # #187 #451 #558
#     103             raise ImportError(
# --> 104                 "FloatProgress not found. Please update jupyter and ipywidgets."
#     105                 " See https://ipywidgets.readthedocs.io/en/stable"
#     106                 "/user_install.html")
#
# ImportError: FloatProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
